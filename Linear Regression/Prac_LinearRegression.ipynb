# %% [markdown]
# # Linear Regression Practice
# #### Author- Atishay Jain
# #### Dataset used- USA_Housing.csv

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('USA_Housing.csv')

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.drop(columns=['Address'], inplace= True)

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.isna()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0                False                False                      False
# 1                False                False                      False
# 2                False                False                      False
# 3                False                False                      False
# 4                False                False                      False
# ...                ...                  ...                        ...
# 4995             False                False                      False
# 4996             False                False                      False
# 4997             False                False                      False
# 4998             False                False                      False
# 4999             False                False                      False
#
#       Avg. Area Number of Bedrooms  Area Population  Price
# ...

# %%
df.isna().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %%
fig, axs= plt.subplots(1,5)
df.plot(kind='scatter', x='Avg. Area Income',y='Price', ax=axs[0], figsize=(30,16))
df.plot(kind='scatter', x='Avg. Area House Age',y='Price', ax=axs[1])
df.plot(kind='scatter', x='Avg. Area Number of Rooms',y='Price', ax=axs[2])
df.plot(kind='scatter', x='Avg. Area Number of Bedrooms',y='Price', ax=axs[3])
df.plot(kind='scatter', x='Area Population',y='Price', ax=axs[4])
# Out:
# <AxesSubplot:xlabel='Area Population', ylabel='Price'>

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(columns=['Price'])
y=df.Price

# %%
x, y
# Out:
# (      Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
#  0         79545.458574             5.682861                   7.009188
#  1         79248.642455             6.002900                   6.730821
#  2         61287.067179             5.865890                   8.512727
#  3         63345.240046             7.188236                   5.586729
#  4         59982.197226             5.040555                   7.839388
#  ...                ...                  ...                        ...
#  4995      60567.944140             7.830362                   6.137356
#  4996      78491.275435             6.999135                   6.576763
#  4997      63390.686886             7.250591                   4.805081
#  4998      68001.331235             5.534388                   7.130144
#  4999      65510.581804             5.992305                   6.792336
#
#        Avg. Area Number of Bedrooms  Area Population
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test=train_test_split(x,y,test_size=0.4, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# -2643568.0100620156
# [2.16554910e+01 1.65154018e+05 1.21027857e+05 2.12906926e+03
#  1.51804898e+01]

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %%
pd.DataFrame(lm.coef_,x.columns, columns=['Coeff'])
# Out:
#                                       Coeff
# Avg. Area Income                  21.655491
# Avg. Area House Age           165154.018219
# Avg. Area Number of Rooms     121027.857267
# Avg. Area Number of Bedrooms    2129.069264
# Area Population                   15.180490

# %%
predictions=lm.predict(x_test)

# %%
plt.figure(figsize=(3, 3), dpi=80)
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 81103.65401

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 10228662791.705574

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 101136.85179846945

# %%
df.head(2)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06

# %%
import statsmodels.formula.api as smf
lm = smf.ols(formula='Price ~ df.iloc[:,0] + df.iloc[:,1] + df.iloc[:,2] + df.iloc[:,3] + df.iloc[:,4]', data=df).fit()
lm.conf_int()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                 1.119e+04
# Date:                Mon, 21 Jun 2021   Prob (F-statistic):               0.00
# Time:                        15:33:34   Log-Likelihood:                -64714.
# No. Observations:                5000   AIC:                         1.294e+05
# Df Residuals:                    4994   BIC:                         1.295e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df.head()
# Out:
#    Avg._Area_Income  Avg._Area_House_Age  Avg._Area_Number_of_Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg._Area_Number_of_Bedrooms  Area_Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
lm.rsquared
# Out:
# 0.9180238195089553

# %%
#Regularization

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge, LassoCV, RidgeCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
sns.set()

# %%
def adj_r2(x,y):
    r2=regression.score(x,y)
    n=x.shape[0]
    p=x.shape[1]
    adjusted_r2=1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(20,30))
plotnumber=1
for column in x:
    if plotnumber<=15:
        ax=plt.subplot(6,3,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column, fontsize=20)
        plt.ylabel("Price", fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[ 1.02865969, -0.29692705,  0.02127433,  0.08806222, -1.31759867],
#        [ 1.00080775,  0.02590164, -0.25550611, -0.72230146,  0.40399945],
#        [-0.68462916, -0.11230283,  1.5162435 ,  0.93084045,  0.07240989],
#        ...,
#        [-0.48723454,  1.28447022, -2.17026949, -1.50025059, -0.29193658],
#        [-0.05459152, -0.44669439,  0.14154061,  1.18205319,  0.65111608],
#        [-0.28831272,  0.01521477, -0.19434166,  0.07185495,  1.04162464]])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=x_scaled
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif['Features']=x.columns

# %%
vif
# Out:
#         VIF                      Features
# 0  1.001159              Avg. Area Income
# 1  1.000577           Avg. Area House Age
# 2  1.273535     Avg. Area Number of Rooms
# 3  1.274413  Avg. Area Number of Bedrooms
# 4  1.001266               Area Population

# %%
variables.shape
# Out:
# (5000, 5)

# %%
x_train, x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25, random_state=355)

# %%
y_train
# Out:
# 4817    5.333868e+05
# 4205    1.550181e+06
# 3531    7.432124e+05
# 2684    2.019424e+06
# 4244    1.124800e+06
#             ...
# 4083    9.999707e+05
# 3985    1.518788e+06
# 2099    1.288069e+06
# 3418    1.895361e+06
# 2690    1.528714e+06
# Name: Price, Length: 3750, dtype: float64

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import pickle

# %%
filename='LR_prac_model.pickle'
pickle.dump(regression, open(filename,'wb'))

# %%
loaded_model=pickle.load(open(filename,'rb'))
a=loaded_model.predict(scaler.transform([[300,100,200,450,49]]))
a
# Out:
# array([38540690.18469766])

# %%
regression.score(x_train,y_train)
# Out:
# 0.9166917008986593

# %%
adj_r2(x_train,y_train)
# Out:
# 0.916580445157338

# %%
regression.score(x_test,y_test)
# Out:
# 0.9215905128043742

# %%
adj_r2(x_test,y_test)
# Out:
# 0.921275362132366

# %%
lasscv=LassoCV(alphas=None,cv=10,max_iter=100000, normalize=True)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(cv=10, max_iter=100000, normalize=True)

# %%
alpha=lasscv.alpha_

# %%
alpha
# Out:
# 4.816569605468993

# %%
lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=4.816569605468993)

# %%
lasso_reg.score(x_train,y_train)
# Out:
# 0.9166917001377666

# %%
#Ridge regression model

# %%
alphas=np.random.uniform(low=0,high=10,size=(50,))
ridgecv=RidgeCV(alphas=alphas,cv=10,normalize=True)
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([4.59877464, 0.85188829, 9.01572254, 0.52019585, 7.19040182,
#        1.13842772, 1.17115297, 9.96516985, 9.01045658, 9.20508507,
#        8.83123418, 4.59323825, 9.34468919, 3.18409698, 8.65442041,
#        4.68383345, 1.53117787, 6.18764782, 0.68612766, 3.4526635 ,
#        6.74979818, 2.3034928 , 0.14987459, 1.41072572, 0.31910779,
#        7.8972947 , 4.50519297, 9.47188625, 6.67645397, 6.26208445,
#        0.91758663, 2.39661826, 7.45339623, 4.66418907, 5.24255787,
#        6.66389901, 7.61532173, 0.50635666, 5.7674452 , 8.88740213,
#        4.5261289 , 6.00140401, 7.54590364, 3.96059635, 0.18597832,
#        1.90208741, 9.02012484, 7.38446384, 5.93934834, 2.69926094]),
#         cv=10, normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.14987459434504746

# %%
ridge_model=Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.14987459434504746)

# %%
ridge_model.score(x_test,y_test)#same score as ridge, so there is no overfitting
# Out:
# 0.9215905318741575

# %%
#Elastic net

# %%
elasticCV=ElasticNetCV(alphas=None, cv=10)

# %%
elasticCV.fit(x_train,y_train)
# Out:
# ElasticNetCV(cv=10)

# %%
elasticCV.alpha_
# Out:
# 447.71282032294073

# %%
elasticCV.l1_ratio
# Out:
# 0.5

# %%
elasticnet_reg= ElasticNet(alpha=elasticCV.alpha_,l1_ratio=0.5)
elasticnet_reg.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=447.71282032294073)

# %%
elasticnet_reg.score(x_test,y_test)
# Out:
# 0.00672748272354029
